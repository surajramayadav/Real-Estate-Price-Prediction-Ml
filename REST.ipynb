# %%
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Rest.csv')

# %%
df.head()
# Out:
#    Area   Price
# 0   250  200000
# 1   300  400000
# 2   400  700000
# 3   600  800000
# 4   125  100000

# %%
plt.scatter(df["Area"],df["Price"])
plt.xlabel('Area')
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(df[["Area"]],df['Price'],test_size=0.3)

# %%
reg=LinearRegression()

# %%
reg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
xtrain
# Out:
#    Area
# 4   125
# 6   100
# 3   600
# 7   450
# 8   400
# 5   250
# 9    50

# %%
ytest
# Out:
# 2    700000
# 1    400000
# 0    200000
# Name: Price, dtype: int64

# %%
reg.predict(xtest)
# Out:
# array([503715.98046057, 373290.30006978, 308077.45987439])

# %%
reg.predict([[900]])
# Out:
# array([1155844.38241451])

# %%
reg.score(xtest,ytest)
# Out:
# 0.5979876705540766

# %%
import seaborn as sns
sns.regplot(x="Area",y="Price",data=df)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Price'>

# %%
import pickle as pk
with open("my_model",'wb') as f:
  pk.dump(reg,f)
